# %%
from sqlalchemy import create_engine
from config import db_password
import pandas as pd

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/We_R_Not_R"

# %%
engine = create_engine(db_string)

# %%
# Load in NBA data.
file_path = "Resources/NBA_Cleaned.csv"
nba_df = pd.read_csv(file_path, index_col= 0)
nba_df.head(10)
# Out:
#                   TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM   FGA  ...  \
# PLAYER                                                                   ...
# Aaron Gordon       ORL   24  2019-20  62  30  32  32.5  14.4  5.4  12.4  ...
# Aaron Holiday      IND   23  2019-20  66  42  24  24.5   9.5  3.5   8.5  ...
# Abdel Nader        OKC   26  2019-20  55  37  18  15.8   6.3  2.2   4.8  ...
# Adam Mokoka        CHI   21  2019-20  11   3   8  10.2   2.9  1.1   2.5  ...
# Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1   2.8  ...
# Al Horford         PHI   34  2019-20  67  39  28  30.2  11.9  4.8  10.6  ...
# Al-Farouq Aminu    ORL   29  2019-20  18   7  11  21.1   4.3  1.4   4.8  ...
# Alec Burks         PHI   28  2019-20  66  21  45  26.6  15.0  4.9  11.6  ...
# Alen Smailagic     GSW   19  2019-20  14   1  13   9.9   4.2  1.4   2.9  ...
# Alex Caruso        LAL   26  2019-20  64  48  16  18.4   5.5  1.9   4.5  ...
#
# ...

# %%
nba_df.to_sql(name='NBA_Cleaned', con=engine)
