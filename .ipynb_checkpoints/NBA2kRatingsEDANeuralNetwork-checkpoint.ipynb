# %% [markdown]
# # NBA Ratings EDA & Neural Network Model

# %%
#Import Required Libraries
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras
from tensorflow.keras import layers

# %%
dfNBA = pd.read_csv('Resources/nba_rankings_2014-2020.csv')

# %%
dfNBA.head()
# Out:
#    Unnamed: 0             PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  \
# 0           0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4
# 1           1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5
# 2           2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3
# 3           3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9
# 4           4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0
#
#    ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0  ...  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1  ...  3.4  1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2  ...  0.7  0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3  ...  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4  ...  0.5  0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0
#
# [5 rows x 32 columns]

# %%
dfNBA.shape
# Out:
# (2412, 32)

# %%
dfNBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2412 entries, 0 to 2411
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2412 non-null   int64
#  1   PLAYER      2412 non-null   object
#  2   TEAM        2412 non-null   object
#  3   AGE         2412 non-null   int64
#  4   SEASON      2412 non-null   object
#  5   GP          2412 non-null   int64
#  6   W           2412 non-null   int64
#  7   L           2412 non-null   int64
#  8   MIN         2412 non-null   float64
#  9   PTS         2412 non-null   float64
#  10  FGM         2412 non-null   float64
#  11  FGA         2412 non-null   float64
#  12  FG%         2412 non-null   float64
#  13  3PM         2412 non-null   float64
#  14  3PA         2412 non-null   float64
#  15  3P%         2412 non-null   float64
#  16  FTM         2412 non-null   float64
#  17  FTA         2412 non-null   float64
#  18  FT%         2412 non-null   float64
#  19  OREB        2412 non-null   float64
#  20  DREB        2412 non-null   float64
#  21  REB         2412 non-null   float64
#  22  AST         2412 non-null   float64
#  23  TOV         2412 non-null   float64
#  24  STL         2412 non-null   float64
#  25  BLK         2412 non-null   float64
#  26  PF          2412 non-null   float64
#  27  FP          2412 non-null   float64
#  28  DD2         2412 non-null   float64
#  29  TD3         2412 non-null   float64
#  30  +/-         2412 non-null   float64
#  31  rankings    2412 non-null   float64
# dtypes: float64(24), int64(5), object(3)
# memory usage: 603.1+ KB

# %%
duplicate_rows_df = dfNBA[dfNBA.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape )
# Out:
# number of duplicate rows:  (0, 32)

# %%
dfNBA.describe()
# Out:
#         Unnamed: 0          AGE           GP            W            L  \
# count  2412.000000  2412.000000  2412.000000  2412.000000  2412.000000
# mean    339.196103    26.314677    55.381012    27.982172    27.398839
# std     200.470761     4.148336    22.816590    15.299014    13.728032
# min       0.000000    19.000000     1.000000     0.000000     0.000000
# 25%     170.000000    23.000000    40.000000    16.000000    17.000000
# 50%     336.500000    26.000000    62.000000    28.000000    28.000000
# 75%     509.250000    29.000000    74.000000    40.000000    37.000000
# max     795.000000    41.000000    83.000000    73.000000    68.000000
#
#                MIN          PTS          FGM          FGA          FG%  ...  \
# count  2412.000000  2412.000000  2412.000000  2412.000000  2412.000000  ...
# mean     21.516086     9.445149     3.502239     7.693615    45.132546  ...
# std       8.762708     6.028712     2.161709     4.574182     8.848778  ...
# min       0.500000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      14.900000     5.000000     1.900000     4.200000    40.875000  ...
# 50%      21.500000     8.000000     3.000000     6.700000    44.500000  ...
# 75%      28.900000    12.800000     4.800000    10.600000    49.000000  ...
# max      38.700000    36.100000    10.900000    24.500000   100.000000  ...
#
#                AST          TOV          STL          BLK           PF  \
# count  2412.000000  2412.000000  2412.000000  2412.000000  2412.000000
# mean      2.040547     1.226658     0.689096     0.442786     1.839096
# std       1.825906     0.812183     0.422630     0.437123     0.723557
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.800000     0.700000     0.400000     0.200000     1.400000
# 50%       1.500000     1.000000     0.600000     0.300000     1.900000
# 75%       2.600000     1.600000     0.900000     0.600000     2.300000
# max      11.700000     5.700000     2.400000     3.700000     5.000000
#
#                 FP          DD2          TD3          +/-     rankings
# count  2412.000000  2412.000000  2412.000000  2412.000000  2412.000000
# mean     19.423839     5.009121     0.236318    -0.114594    75.656716
# std      10.780126    10.114069     1.708944     3.004522     5.797701
# min       0.000000     0.000000     0.000000   -18.000000    62.000000
# 25%      11.600000     0.000000     0.000000    -1.900000    72.000000
# 50%      17.500000     1.000000     0.000000    -0.200000    75.000000
# 75%      25.700000     5.000000     0.000000     1.500000    78.000000
# max      60.600000    69.000000    42.000000    13.200000    98.000000
#
# [8 rows x 29 columns]

# %%
dfNBA.isnull()
# Out:
#       Unnamed: 0  PLAYER   TEAM    AGE  SEASON     GP      W      L    MIN  \
# 0          False   False  False  False   False  False  False  False  False
# 1          False   False  False  False   False  False  False  False  False
# 2          False   False  False  False   False  False  False  False  False
# 3          False   False  False  False   False  False  False  False  False
# 4          False   False  False  False   False  False  False  False  False
# ...          ...     ...    ...    ...     ...    ...    ...    ...    ...
# 2407       False   False  False  False   False  False  False  False  False
# 2408       False   False  False  False   False  False  False  False  False
# 2409       False   False  False  False   False  False  False  False  False
# 2410       False   False  False  False   False  False  False  False  False
# 2411       False   False  False  False   False  False  False  False  False
#
#         PTS  ...    AST    TOV    STL    BLK     PF     FP    DD2    TD3  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...  False  False  False  False  False  False  False  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2407  False  ...  False  False  False  False  False  False  False  False
# 2408  False  ...  False  False  False  False  False  False  False  False
# 2409  False  ...  False  False  False  False  False  False  False  False
# 2410  False  ...  False  False  False  False  False  False  False  False
# 2411  False  ...  False  False  False  False  False  False  False  False
#
#         +/-  rankings
# 0     False     False
# 1     False     False
# 2     False     False
# 3     False     False
# 4     False     False
# ...     ...       ...
# 2407  False     False
# 2408  False     False
# 2409  False     False
# 2410  False     False
# 2411  False     False
#
# [2412 rows x 32 columns]

# %%
dfNBA.isna().sum()
# Out:
# Unnamed: 0    0
# PLAYER        0
# TEAM          0
# AGE           0
# SEASON        0
# GP            0
# W             0
# L             0
# MIN           0
# PTS           0
# FGM           0
# FGA           0
# FG%           0
# 3PM           0
# 3PA           0
# 3P%           0
# FTM           0
# FTA           0
# FT%           0
# OREB          0
# DREB          0
# REB           0
# AST           0
# TOV           0
# STL           0
# BLK           0
# PF            0
# FP            0
# DD2           0
# TD3           0
# +/-           0
# rankings      0
# dtype: int64

# %%
dfNBA.head()
# Out:
#    Unnamed: 0             PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  \
# 0           0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4
# 1           1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5
# 2           2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3
# 3           3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9
# 4           4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0
#
#    ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0  ...  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1  ...  3.4  1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2  ...  0.7  0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3  ...  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4  ...  0.5  0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0
#
# [5 rows x 32 columns]

# %%
train_dataset_all = dfNBA.sample(frac=0.8, random_state=0)
test_dataset_all = dfNBA.drop(train_dataset_all.index)
df_20192020_all = dfNBA[(dfNBA.SEASON == '2019-20')]

# %%
train_dataset_all
# Out:
#       Unnamed: 0            PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  \
# 964          190  Dennis Smith Jr.  DAL   20  2017-18  69  22  47  29.7  15.2
# 2189         248      JaVale McGee  DEN   27  2014-15  23   8  15  11.1   4.6
# 148          183        Elie Okobo  PHX   22  2019-20  55  23  32  13.1   4.0
# 1989         523       Salah Mejri  DAL   30  2015-16  34  16  18  11.7   3.7
# 981          226    Doug McDermott  DAL   26  2017-18  81  30  51  21.8   7.8
# ...          ...               ...  ...  ...      ...  ..  ..  ..   ...   ...
# 100          126     Davis Bertans  WAS   27  2019-20  54  20  34  29.3  15.4
# 1270         763        Tyus Jones  MIN   22  2017-18  82  47  35  17.9   5.1
# 1243         712        Thon Maker  MIL   21  2017-18  74  40  34  16.7   4.8
# 741          466        Lonzo Ball  LAL   21  2018-19  47  25  22  30.3   9.9
# 334          415      Marcus Smart  BOS   26  2019-20  60  39  21  32.0  12.9
#
#       ...  AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-  rankings
# 964   ...  5.2  2.8  1.0  0.3  2.2  28.6  6.0  1.0 -4.7      78.0
# 2189  ...  0.1  0.8  0.1  0.9  1.3  10.1  0.0  0.0 -3.0      75.0
# 148   ...  2.1  0.7  0.4  0.1  1.0   9.9  0.0  0.0 -1.2      71.0
# 1989  ...  0.3  0.7  0.2  1.1  1.6  11.7  3.0  0.0  1.3      73.0
# 981   ...  1.0  0.7  0.2  0.2  1.5  12.8  0.0  0.0 -0.4      73.0
# ...   ...  ...  ...  ...  ...  ...   ...  ...  ...  ...       ...
# 100   ...  1.7  1.1  0.7  0.6  2.6  26.2  1.0  0.0 -0.3      79.0
# 1270  ...  2.8  0.7  1.2  0.1  1.3  14.2  0.0  0.0  2.2      74.0
# 1243  ...  0.6  0.6  0.5  0.7  2.2  12.5  0.0  0.0 -2.2      72.0
# 741   ...  5.4  2.2  1.5  0.4  2.4  27.9  4.0  1.0 -0.3      79.0
# 334   ...  4.9  1.7  1.7  0.5  2.7  29.5  3.0  0.0  4.7      80.0
#
# [1930 rows x 32 columns]

# %%
test_dataset_all
# Out:
#       Unnamed: 0              PLAYER TEAM  AGE   SEASON  GP   W   L   MIN  \
# 0              0        Aaron Gordon  ORL   24  2019-20  62  30  32  32.5
# 3              3         Adam Mokoka  CHI   21  2019-20  11   3   8  10.2
# 7              7          Alec Burks  PHI   28  2019-20  66  21  45  26.6
# 24            24    Anthony Tolliver  MEM   35  2019-20  55  24  31  15.9
# 25            25  Antonius Cleveland  DAL   26  2019-20  11   6   5   4.2
# ...          ...                 ...  ...  ...      ...  ..  ..  ..   ...
# 2376         593     Thabo Sefolosha  ATL   31  2014-15  52  43   9  18.8
# 2384         601       Tobias Harris  ORL   22  2014-15  68  20  48  34.8
# 2385         603          Tony Allen  MEM   33  2014-15  63  46  17  26.2
# 2393         613        Troy Daniels  CHA   23  2014-15  47  15  32   8.5
# 2408         643     Wilson Chandler  DEN   28  2014-15  78  28  50  31.7
#
#        PTS  ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0     14.4  ...  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 3      2.9  ...  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 7     15.0  ...  2.9  1.4  0.9  0.3  1.9  26.7   1.0  0.0 -3.4      77.0
# 24     3.6  ...  0.8  0.6  0.3  0.2  1.3   9.2   1.0  0.0 -1.9      71.0
# 25     1.0  ...  0.1  0.2  0.1  0.3  0.7   2.8   0.0  0.0 -1.1      67.0
# ...    ...  ...  ...  ...  ...  ...  ...   ...   ...  ...  ...       ...
# 2376   5.3  ...  1.4  0.7  1.0  0.4  1.3  16.2   1.0  0.0  3.3      74.0
# 2384  17.1  ...  1.8  1.7  1.0  0.5  2.0  30.4  11.0  0.0 -4.3      79.0
# 2385   8.6  ...  1.4  1.4  2.0  0.5  2.6  22.1   2.0  0.0  3.9      78.0
# 2393   3.7  ...  0.5  0.4  0.1  0.0  0.9   5.3   0.0  0.0 -1.8      67.0
# 2408  13.9  ...  1.7  1.4  0.7  0.4  3.0  25.7   8.0  0.0 -2.8      77.0
#
# [482 rows x 32 columns]

# %%
df_20192020_all
# Out:
#      Unnamed: 0             PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  \
# 0             0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4
# 1             1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5
# 2             2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3
# 3             3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9
# 4             4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0
# ..          ...                ...  ...  ...      ...  ..  ..  ..   ...   ...
# 502         623        Zach LaVine  CHI   25  2019-20  60  20  40  34.8  25.5
# 503         624   Zach Norvell Jr.  GSW   22  2019-20   5   2   3   8.2   2.0
# 504         628       Zhaire Smith  PHI   21  2019-20   7   3   4   4.6   1.1
# 505         629    Zion Williamson  NOP   19  2019-20  24  11  13  27.8  22.5
# 506         630     Zylan Cheatham  NOP   24  2019-20   4   2   2  12.8   3.0
#
#      ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0    ...  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1    ...  3.4  1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2    ...  0.7  0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3    ...  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4    ...  0.5  0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0
# ..   ...  ...  ...  ...  ...  ...   ...   ...  ...  ...       ...
# 502  ...  4.2  3.4  1.5  0.5  2.2  40.0   2.0  0.0 -3.2      85.0
# 503  ...  0.6  0.6  0.4  0.0  0.8   4.9   0.0  0.0 -5.4      68.0
# 504  ...  0.3  0.3  0.4  0.0  0.6   2.9   0.0  0.0 -1.4      70.0
# 505  ...  2.1  2.5  0.7  0.4  1.8  33.8   2.0  0.0  2.6      86.0
# 506  ...  0.8  1.0  0.3  0.3  2.5   7.3   0.0  0.0 -7.0      67.0
#
# [507 rows x 32 columns]

# %%
# Drop the non-beneficial ID columns
train_dataset = train_dataset_all.drop(columns=["PLAYER", "TEAM", "SEASON", "Unnamed: 0"], axis=1)
test_dataset = test_dataset_all.drop(columns=["PLAYER", "TEAM", "SEASON", "Unnamed: 0"], axis=1)
df_20192020_dataset = df_20192020_all.drop(columns=["PLAYER", "TEAM", "SEASON", "Unnamed: 0"], axis=1)

# %%
train_dataset
# Out:
#       AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...  AST  TOV  STL  \
# 2393   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...  0.5  0.4  0.1
# 2408   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...  1.7  1.4  0.7
#
#       BLK   PF    FP   DD2  TD3  +/-  rankings
# 0     0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 3     0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 7     0.3  1.9  26.7   1.0  0.0 -3.4      77.0
# 24    0.2  1.3   9.2   1.0  0.0 -1.9      71.0
# 25    0.3  0.7   2.8   0.0  0.0 -1.1      67.0
# ...   ...  ...   ...   ...  ...  ...       ...
# 2376  0.4  1.3  16.2   1.0  0.0  3.3      74.0
# 2384  0.5  2.0  30.4  11.0  0.0 -4.3      79.0
# 2385  0.5  2.6  22.1   2.0  0.0  3.9      78.0
# 2393  0.0  0.9   5.3   0.0  0.0 -1.8      67.0
# 2408  0.4  3.0  25.7   8.0  0.0 -2.8      77.0
#
# [482 rows x 28 columns]

# %%
df_20192020_dataset
# Out:
#      AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...  AST  TOV  STL  \
# 0     24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  3.7  1.6  0.8
# 1     23  66  42  24  24.5   9.5  3.5   8.5  41.4  1.3  ...  3.4  1.3  0.8
# 2     26  55  37  18  15.8   6.3  2.2   4.8  46.8  0.9  ...  0.7  0.8  0.4
# 3     21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...  0.4  0.2  0.4
# 4     23  33   9  24  11.2   3.0  1.1   2.8  38.0  0.6  ...  0.5  0.2  0.2
# ..   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...  ...  ...  ...
# 502   25  60  20  40  34.8  25.5  9.0  20.0  45.0  3.1  ...  4.2  3.4  1.5
# 503   22   5   2   3   8.2   2.0  0.6   2.4  25.0  0.6  ...  0.6  0.6  0.4
# 504   21   7   3   4   4.6   1.1  0.4   1.6  27.3  0.0  ...  0.3  0.3  0.4
# 505   19  24  11  13  27.8  22.5  8.8  15.0  58.3  0.3  ...  2.1  2.5  0.7
# 506   24   4   2   2  12.8   3.0  1.5   2.3  66.7  0.0  ...  0.8  1.0  0.3
#
#      BLK   PF    FP   DD2  TD3  +/-  rankings
# 0    0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1    0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2    0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3    0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4    0.1  1.5   6.3   0.0  0.0 -1.7      71.0
# ..   ...  ...   ...   ...  ...  ...       ...
# 502  0.5  2.2  40.0   2.0  0.0 -3.2      85.0
# 503  0.0  0.8   4.9   0.0  0.0 -5.4      68.0
# 504  0.0  0.6   2.9   0.0  0.0 -1.4      70.0
# 505  0.4  1.8  33.8   2.0  0.0  2.6      86.0
# 506  0.3  2.5   7.3   0.0  0.0 -7.0      67.0
#
# [507 rows x 28 columns]

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()
features_201920 = df_20192020_dataset.copy()

train_labels = train_features.pop('rankings')
test_labels = test_features.pop('rankings')
labels_201920 = df_20192020_dataset.pop('rankings')

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                mean        std
# AGE       26.291710   4.139905
# GP        55.551295  22.775090
# W         28.069430  15.274551
# L         27.481865  13.591993
# MIN       21.715959   8.750626
# PTS        9.589378   6.066165
# FGM        3.555181   2.173066
# FGA        7.801295   4.614076
# FG%       45.210155   8.758963
# 3PM        0.891606   0.819091
# 3PA        2.513834   2.129287
# 3P%       29.086736  14.342404
# FTM        1.590415   1.418294
# FTA        2.089067   1.743863
# FT%       72.596839  16.710681
# OREB       0.953990   0.819619
# DREB       3.075855   1.854840
# REB        4.025907   2.526636
# AST        2.039482   1.792223
# TOV        1.241451   0.819084
# STL        0.697720   0.420675
# BLK        0.450829   0.444565
# PF         1.849171   0.714431
# FP        19.671710  10.759107
# DD2        5.152332  10.286392
# TD3        0.230570   1.684620
# +/-       -0.130933   2.946978
# rankings  75.761658   5.740110

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
normalizer.adapt(np.array(train_features))

# %%
minutes = np.array(train_features['MIN'])
minutes_normalizer = layers.Normalization(input_shape=[1,], axis=None)
minutes_normalizer.adapt(minutes)

# %%
minutes_model = tf.keras.Sequential([
    minutes_normalizer,
    layers.Dense(units=1)
])

minutes_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 1)                3
#  ion)
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %%
minutes_model.predict(minutes[:10])
# Out:
# array([[-0.5996978 ],
#        [ 0.797387  ],
#        [ 0.6471628 ],
#        [ 0.75231975],
#        [-0.00631225],
#        [-0.0438683 ],
#        [ 1.4358397 ],
#        [ 0.56453955],
#        [-0.26169345],
#        [ 0.6246292 ]], dtype=float32)

# %%
minutes_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = minutes_model.fit(
    train_features['MIN'],
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)
# Out:
# Wall time: 3.5 s

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  2.738440  2.467587     95
# 96  2.735523  2.485783     96
# 97  2.735290  2.488310     97
# 98  2.744158  2.481420     98
# 99  2.736877  2.475695     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error [Rating]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %%
test_results = {}

test_results['minutes_model'] = minutes_model.evaluate(
    test_features['MIN'],
    test_labels, verbose=0)

# %%
x = tf.linspace(0.0, 250, 251)
y = minutes_model.predict(x)

# %%
def plot_Minutes(x, y):
  plt.scatter(train_features['MIN'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Min')
  plt.ylabel('Rating')
  plt.legend()

# %%
plot_Minutes(x, y)

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %%
linear_model.predict(train_features[:10])
# Out:
# array([[-3.3061488 ],
#        [ 3.4281645 ],
#        [-0.0236378 ],
#        [ 3.8878107 ],
#        [-0.40732107],
#        [ 0.8326396 ],
#        [ 1.4725368 ],
#        [ 0.6821786 ],
#        [-2.5526114 ],
#        [ 1.1135564 ]], dtype=float32)

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(27, 1) dtype=float32, numpy=
# array([[ 0.39838636],
#        [-0.19513622],
#        [-0.24110524],
#        [-0.45768797],
#        [ 0.19419867],
#        [-0.03874633],
#        [-0.38917905],
#        [ 0.16360003],
#        [ 0.42941487],
#        [-0.09388104],
#        [-0.01482296],
#        [-0.36448568],
#        [ 0.4142567 ],
#        [-0.11799467],
#        [ 0.26946563],
#        [-0.0544202 ],
#        [-0.09928656],
#        [-0.42926598],
#        [ 0.01063943],
#        [-0.44271135],
#        [-0.34512597],
#        [ 0.42227393],
#        [-0.23960039],
#        [ 0.24397343],
#        [-0.33574948],
#        [-0.16870514],
#        [ 0.24861932]], dtype=float32)>

# %%
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features,
    train_labels,
    epochs=100,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)
# Out:
# Wall time: 3.56 s

# %%
plot_loss(history)

# %%
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
dnn_min_model = build_and_compile_model(minutes_normalizer)

# %%
dnn_min_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 1)                3
#  ion)
#
#  dense_2 (Dense)             (None, 64)                128
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,356
# Trainable params: 4,353
# Non-trainable params: 3
# _________________________________________________________________

# %%
# %%time
history = dnn_min_model.fit(
    train_features['MIN'],
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# Wall time: 4.04 s

# %%
plot_loss(history)

# %%
x = tf.linspace(0.0, 250, 251)
y = dnn_min_model.predict(x)

# %%
plot_Minutes(x, y)

# %%
test_results['dnn_min_model'] = dnn_min_model.evaluate(
    test_features['MIN'], test_labels,
    verbose=0)

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 27)               55
#  n)
#
#  dense_5 (Dense)             (None, 64)                1792
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,072
# Trainable params: 6,017
# Non-trainable params: 55
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features,
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# Wall time: 4.19 s

# %%
plot_loss(history)

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Rating]']).T
# Out:
#                Mean absolute error [Rating]
# minutes_model                      2.686655
# linear_model                       1.449287
# dnn_min_model                      2.452372
# dnn_model                          1.706767

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Ratings]')
plt.ylabel('Predictions [Ratings]')
lims = [0, 100]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Ratings]')
_ = plt.ylabel('Count')

# %%
dnn_model.save('dnn_model')
# Out:
# INFO:tensorflow:Assets written to: dnn_model\assets

# %%
reloaded = tf.keras.models.load_model('dnn_model')

test_results['reloaded'] = reloaded.evaluate(
    test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error Ratings']).T
# Out:
#                Mean absolute error Ratings
# minutes_model                     2.686655
# linear_model                      1.449287
# dnn_min_model                     2.452372
# dnn_model                         1.706767
# reloaded                          1.706767

# %%
test_features
# Out:
#       AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...  REB  AST  TOV  \
# 0      24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  7.7  3.7  1.6
# 3      21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...  0.9  0.4  0.2
# 7      28  66  21  45  26.6  15.0  4.9  11.6  41.8  1.8  ...  4.3  2.9  1.4
# 24     35  55  24  31  15.9   3.6  1.2   3.3  35.7  0.9  ...  2.8  0.8  0.6
# 25     26  11   6   5   4.2   1.0  0.4   1.3  28.6  0.0  ...  0.6  0.1  0.2
# ...   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...  ...  ...  ...
# 2376   31  52  43   9  18.8   5.3  2.0   4.8  41.8  0.5  ...  4.3  1.4  0.7
# 2384   22  68  20  48  34.8  17.1  6.5  14.0  46.6  1.3  ...  6.3  1.8  1.7
# 2385   33  63  46  17  26.2   8.6  3.6   7.2  49.5  0.2  ...  4.4  1.4  1.4
# 2393   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...  0.7  0.5  0.4
# 2408   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...  6.1  1.7  1.4
#
#       STL  BLK   PF    FP   DD2  TD3  +/-
# 0     0.8  0.6  2.0  31.9  20.0  1.0 -1.1
# 3     0.4  0.0  1.5   5.5   0.0  0.0  4.5
# 7     0.9  0.3  1.9  26.7   1.0  0.0 -3.4
# 24    0.3  0.2  1.3   9.2   1.0  0.0 -1.9
# 25    0.1  0.3  0.7   2.8   0.0  0.0 -1.1
# ...   ...  ...  ...   ...   ...  ...  ...
# 2376  1.0  0.4  1.3  16.2   1.0  0.0  3.3
# 2384  1.0  0.5  2.0  30.4  11.0  0.0 -4.3
# 2385  2.0  0.5  2.6  22.1   2.0  0.0  3.9
# 2393  0.1  0.0  0.9   5.3   0.0  0.0 -1.8
# 2408  0.7  0.4  3.0  25.7   8.0  0.0 -2.8
#
# [482 rows x 27 columns]

# %%
test_labels
# Out:
# 0       80.0
# 3       68.0
# 7       77.0
# 24      71.0
# 25      67.0
#         ...
# 2376    74.0
# 2384    79.0
# 2385    78.0
# 2393    67.0
# 2408    77.0
#
#       BLK   PF    FP   DD2  TD3  +/-  rankings
# 0     0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 3     0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 7     0.3  1.9  26.7   1.0  0.0 -3.4      77.0
# 24    0.2  1.3   9.2   1.0  0.0 -1.9      71.0
# 25    0.3  0.7   2.8   0.0  0.0 -1.1      67.0
# ...   ...  ...   ...   ...  ...  ...       ...
# 2376  0.4  1.3  16.2   1.0  0.0  3.3      74.0
# 2384  0.5  2.0  30.4  11.0  0.0 -4.3      79.0
# 2385  0.5  2.6  22.1   2.0  0.0  3.9      78.0
# 2393  0.0  0.9   5.3   0.0  0.0 -1.8      67.0
# 2408  0.4  3.0  25.7   8.0  0.0 -2.8      77.0
#
# [482 rows x 28 columns]

# %%
test_dataset_all.drop(test_features, axis=1, inplace=True)

# %%
test_dataset_all.drop(['Unnamed: 0', 'rankings'], axis=1)
# Out:
#                   PLAYER TEAM   SEASON
# 0           Aaron Gordon  ORL  2019-20
# 3            Adam Mokoka  CHI  2019-20
# 7             Alec Burks  PHI  2019-20
# 24      Anthony Tolliver  MEM  2019-20
# 25    Antonius Cleveland  DAL  2019-20
# ...                  ...  ...      ...
# 2376     Thabo Sefolosha  ATL  2014-15
# 2384       Tobias Harris  ORL  2014-15
# 2385          Tony Allen  MEM  2014-15
# 2393        Troy Daniels  CHA  2014-15
# 2408     Wilson Chandler  DEN  2014-15
#
# [482 rows x 3 columns]

# %%
test_dataset_all
# Out:
#       Unnamed: 0              PLAYER TEAM   SEASON  rankings
# 0              0        Aaron Gordon  ORL  2019-20      80.0
# 3              3         Adam Mokoka  CHI  2019-20      68.0
# 7              7          Alec Burks  PHI  2019-20      77.0
# 24            24    Anthony Tolliver  MEM  2019-20      71.0
# 25            25  Antonius Cleveland  DAL  2019-20      67.0
# ...          ...                 ...  ...      ...       ...
# 2376         593     Thabo Sefolosha  ATL  2014-15      74.0
# 2384         601       Tobias Harris  ORL  2014-15      79.0
# 2385         603          Tony Allen  MEM  2014-15      78.0
# 2393         613        Troy Daniels  CHA  2014-15      67.0
# 2408         643     Wilson Chandler  DEN  2014-15      77.0
#
# [482 rows x 5 columns]

# %%
testdf = pd.DataFrame.merge(testdf,test_dataset_all,left_index=True, right_index=True)

# %%
testdf
# Out:
#       AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...    FP   DD2  TD3  \
# 0      24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  31.9  20.0  1.0
# 3      21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...   5.5   0.0  0.0
# 7      28  66  21  45  26.6  15.0  4.9  11.6  41.8  1.8  ...  26.7   1.0  0.0
# 24     35  55  24  31  15.9   3.6  1.2   3.3  35.7  0.9  ...   9.2   1.0  0.0
# 25     26  11   6   5   4.2   1.0  0.4   1.3  28.6  0.0  ...   2.8   0.0  0.0
# ...   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...   ...   ...  ...
# 2376   31  52  43   9  18.8   5.3  2.0   4.8  41.8  0.5  ...  16.2   1.0  0.0
# 2384   22  68  20  48  34.8  17.1  6.5  14.0  46.6  1.3  ...  30.4  11.0  0.0
# 2385   33  63  46  17  26.2   8.6  3.6   7.2  49.5  0.2  ...  22.1   2.0  0.0
# 2393   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...   5.3   0.0  0.0
# 2408   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...  25.7   8.0  0.0
#
#       +/-  rankings_x  Unnamed: 0              PLAYER  TEAM   SEASON  \
# 0    -1.1        80.0           0        Aaron Gordon   ORL  2019-20
# 3     4.5        68.0           3         Adam Mokoka   CHI  2019-20
# 7    -3.4        77.0           7          Alec Burks   PHI  2019-20
# 24   -1.9        71.0          24    Anthony Tolliver   MEM  2019-20
# 25   -1.1        67.0          25  Antonius Cleveland   DAL  2019-20
# ...   ...         ...         ...                 ...   ...      ...
# 2376  3.3        74.0         593     Thabo Sefolosha   ATL  2014-15
# 2384 -4.3        79.0         601       Tobias Harris   ORL  2014-15
# 2385  3.9        78.0         603          Tony Allen   MEM  2014-15
# 2393 -1.8        67.0         613        Troy Daniels   CHA  2014-15
# 2408 -2.8        77.0         643     Wilson Chandler   DEN  2014-15
#
#       rankings_y
# 0           80.0
# 3           68.0
# 7           77.0
# 24          71.0
# 25          67.0
# ...          ...
# 2376        74.0
# 2384        79.0
# 2385        78.0
# 2393        67.0
# 2408        77.0
#
# [482 rows x 33 columns]

# %%
testdf.reset_index(drop=True,inplace=True)

# %%
testdf
# Out:
#      AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...    FP   DD2  TD3  \
# 0     24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  31.9  20.0  1.0
# 1     21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...   5.5   0.0  0.0
# 2     28  66  21  45  26.6  15.0  4.9  11.6  41.8  1.8  ...  26.7   1.0  0.0
# 3     35  55  24  31  15.9   3.6  1.2   3.3  35.7  0.9  ...   9.2   1.0  0.0
# 4     26  11   6   5   4.2   1.0  0.4   1.3  28.6  0.0  ...   2.8   0.0  0.0
# ..   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...   ...   ...  ...
# 477   31  52  43   9  18.8   5.3  2.0   4.8  41.8  0.5  ...  16.2   1.0  0.0
# 478   22  68  20  48  34.8  17.1  6.5  14.0  46.6  1.3  ...  30.4  11.0  0.0
# 479   33  63  46  17  26.2   8.6  3.6   7.2  49.5  0.2  ...  22.1   2.0  0.0
# 480   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...   5.3   0.0  0.0
# 481   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...  25.7   8.0  0.0
#
#      +/-  rankings_x  Unnamed: 0              PLAYER  TEAM   SEASON  \
# 0   -1.1        80.0           0        Aaron Gordon   ORL  2019-20
# 1    4.5        68.0           3         Adam Mokoka   CHI  2019-20
# 2   -3.4        77.0           7          Alec Burks   PHI  2019-20
# 3   -1.9        71.0          24    Anthony Tolliver   MEM  2019-20
# 4   -1.1        67.0          25  Antonius Cleveland   DAL  2019-20
# ..   ...         ...         ...                 ...   ...      ...
# 477  3.3        74.0         593     Thabo Sefolosha   ATL  2014-15
# 478 -4.3        79.0         601       Tobias Harris   ORL  2014-15
# 479  3.9        78.0         603          Tony Allen   MEM  2014-15
# 480 -1.8        67.0         613        Troy Daniels   CHA  2014-15
# 481 -2.8        77.0         643     Wilson Chandler   DEN  2014-15
#
#      rankings_y
# 0          80.0
# 1          68.0
# 2          77.0
# 3          71.0
# 4          67.0
# ..          ...
# 477        74.0
# 478        79.0
# 479        78.0
# 480        67.0
# 481        77.0
#
# [482 rows x 33 columns]

# %%
preddf = pd.DataFrame(test_predictions)

# %%
preddf
# Out:
#              0
# 0    78.471642
# 1    69.997940
# 2    76.666870
# 3    70.403534
# 4    69.219925
# ..         ...
# 477  75.694992
# 478  77.901909
# 479  80.103775
# 480  69.216423
# 481  77.170227
#
# [482 rows x 1 columns]

# %%
nbatestpred = pd.DataFrame.merge(testdf,preddf, left_index=True, right_index=True)

# %%
nbatestpred
# Out:
#      AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...   DD2  TD3  +/-  \
# 0     24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  20.0  1.0 -1.1
# 1     21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...   0.0  0.0  4.5
# 2     28  66  21  45  26.6  15.0  4.9  11.6  41.8  1.8  ...   1.0  0.0 -3.4
# 3     35  55  24  31  15.9   3.6  1.2   3.3  35.7  0.9  ...   1.0  0.0 -1.9
# 4     26  11   6   5   4.2   1.0  0.4   1.3  28.6  0.0  ...   0.0  0.0 -1.1
# ..   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...   ...  ...  ...
# 477   31  52  43   9  18.8   5.3  2.0   4.8  41.8  0.5  ...   1.0  0.0  3.3
# 478   22  68  20  48  34.8  17.1  6.5  14.0  46.6  1.3  ...  11.0  0.0 -4.3
# 479   33  63  46  17  26.2   8.6  3.6   7.2  49.5  0.2  ...   2.0  0.0  3.9
# 480   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...   0.0  0.0 -1.8
# 481   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...   8.0  0.0 -2.8
#
#      rankings_x  Unnamed: 0              PLAYER  TEAM   SEASON  rankings_y  \
# 0          80.0           0        Aaron Gordon   ORL  2019-20        80.0
# 1          68.0           3         Adam Mokoka   CHI  2019-20        68.0
# 2          77.0           7          Alec Burks   PHI  2019-20        77.0
# 3          71.0          24    Anthony Tolliver   MEM  2019-20        71.0
# 4          67.0          25  Antonius Cleveland   DAL  2019-20        67.0
# ..          ...         ...                 ...   ...      ...         ...
# 477        74.0         593     Thabo Sefolosha   ATL  2014-15        74.0
# 478        79.0         601       Tobias Harris   ORL  2014-15        79.0
# 479        78.0         603          Tony Allen   MEM  2014-15        78.0
# 480        67.0         613        Troy Daniels   CHA  2014-15        67.0
# 481        77.0         643     Wilson Chandler   DEN  2014-15        77.0
#
#              0
# 0    78.471642
# 1    69.997940
# 2    76.666870
# 3    70.403534
# 4    69.219925
# ..         ...
# 477  75.694992
# 478  77.901909
# 479  80.103775
# 480  69.216423
# 481  77.170227
#
# [482 rows x 34 columns]

# %%
nbatestpred.drop(['rankings_x', 'Unnamed: 0'], axis=1, inplace=True)

# %%
nbatestpred.rename(columns={'rankings_y': 'rankings'}, inplace=True)

# %%
nbatestpred
# Out:
#      AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...   PF    FP   DD2  \
# 0     24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  2.0  31.9  20.0
# 1     21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...  1.5   5.5   0.0
# 2     28  66  21  45  26.6  15.0  4.9  11.6  41.8  1.8  ...  1.9  26.7   1.0
# 3     35  55  24  31  15.9   3.6  1.2   3.3  35.7  0.9  ...  1.3   9.2   1.0
# 4     26  11   6   5   4.2   1.0  0.4   1.3  28.6  0.0  ...  0.7   2.8   0.0
# ..   ...  ..  ..  ..   ...   ...  ...   ...   ...  ...  ...  ...   ...   ...
# 477   31  52  43   9  18.8   5.3  2.0   4.8  41.8  0.5  ...  1.3  16.2   1.0
# 478   22  68  20  48  34.8  17.1  6.5  14.0  46.6  1.3  ...  2.0  30.4  11.0
# 479   33  63  46  17  26.2   8.6  3.6   7.2  49.5  0.2  ...  2.6  22.1   2.0
# 480   23  47  15  32   8.5   3.7  1.3   3.5  37.0  0.9  ...  0.9   5.3   0.0
# 481   28  78  28  50  31.7  13.9  5.4  12.5  42.9  1.8  ...  3.0  25.7   8.0
#
#      TD3  +/-              PLAYER  TEAM   SEASON  rankings          0
# 0    1.0 -1.1        Aaron Gordon   ORL  2019-20      80.0  78.471642
# 1    0.0  4.5         Adam Mokoka   CHI  2019-20      68.0  69.997940
# 2    0.0 -3.4          Alec Burks   PHI  2019-20      77.0  76.666870
# 3    0.0 -1.9    Anthony Tolliver   MEM  2019-20      71.0  70.403534
# 4    0.0 -1.1  Antonius Cleveland   DAL  2019-20      67.0  69.219925
# ..   ...  ...                 ...   ...      ...       ...        ...
# 477  0.0  3.3     Thabo Sefolosha   ATL  2014-15      74.0  75.694992
# 478  0.0 -4.3       Tobias Harris   ORL  2014-15      79.0  77.901909
# 479  0.0  3.9          Tony Allen   MEM  2014-15      78.0  80.103775
# 480  0.0 -1.8        Troy Daniels   CHA  2014-15      67.0  69.216423
# 481  0.0 -2.8     Wilson Chandler   DEN  2014-15      77.0  77.170227
#
# [482 rows x 32 columns]

# %%
nbatestpred.to_csv('NBATestPred.csv')
