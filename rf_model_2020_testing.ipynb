# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import sklearn as skl

# %%
raw_df = pd.read_csv('nba_rankings_2014-2020.csv', index_col=False)
raw_df.head()
# Out:
#    Unnamed: 0             PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  \
# 0           0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4
# 1           1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5
# 2           2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3
# 3           3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9
# 4           4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0
#
#    ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0  ...  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1  ...  3.4  1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2  ...  0.7  0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3  ...  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4  ...  0.5  0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0
#
# [5 rows x 32 columns]

# %%
train_seasons = raw_df[(raw_df.SEASON != '2019-20')]
train_seasons
test_season = raw_df[(raw_df.SEASON == '2019-20')]
test_season = test_season.drop('Unnamed: 0', axis=1)
test_season.head()
# Out:
#               PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM  ...  \
# 0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4  5.4  ...
# 1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5  3.5  ...
# 2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3  2.2  ...
# 3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9  1.1  ...
# 4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1  ...
#
#    AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# 1  3.4  1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0
# 2  0.7  0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0
# 3  0.4  0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0
# 4  0.5  0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0
#
# [5 rows x 31 columns]

# %%
X = train_seasons.copy()
X = X.drop("rankings", axis=1)
X = X.drop("PLAYER", axis=1)
X = X.drop("TEAM", axis=1)
X = X.drop("SEASON", axis=1)
X = X.drop('Unnamed: 0', axis=1)

X.head()
# Out:
#      AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...  REB  AST  TOV  \
# 507   23  78  40  38  33.8  16.0  6.0  13.4  44.9  1.6  ...  7.4  3.7  2.1
# 508   22  50  31  19  12.9   5.9  2.1   5.2  40.1  0.9  ...  1.3  1.7  0.8
# 509   25  61  38  23  11.4   4.0  1.5   3.5  42.3  0.5  ...  1.9  0.3  0.4
# 510   33  68  41  27  29.0  13.6  5.7  10.6  53.5  1.1  ...  6.7  4.2  1.5
# 511   28  81  52  29  28.3   9.4  3.2   7.3  43.3  1.2  ...  7.5  1.3  0.9
#
#      STL  BLK   PF    FP   DD2  TD3  +/-
# 507  0.7  0.7  2.2  32.6  19.0  0.0  1.4
# 508  0.4  0.3  1.4  11.3   0.0  0.0  2.0
# 509  0.3  0.2  1.1   7.9   0.0  0.0 -2.5
# 510  0.9  1.3  1.9  32.8  10.0  1.0  3.8
# 511  0.8  0.4  1.8  23.2  12.0  0.0  4.7
#
# [5 rows x 27 columns]

# %%
y = train_seasons["rankings"].ravel()
y[:5]
# Out:
# array([81., 73., 70., 85., 77.])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2)

# %%
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=128, random_state=2)

# %%
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
test_df = test_season.copy()
test_df = test_df.drop("PLAYER", axis=1)
test_df = test_df.drop("TEAM", axis=1)
test_df = test_df.drop("SEASON", axis=1)
test_df.head()
test_x = test_df.drop("rankings", axis=1)
test_y = test_df['rankings'].ravel()
test_x.head()
# Out:
#    AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  ...  REB  AST  TOV  STL  \
# 0   24  62  30  32  32.5  14.4  5.4  12.4  43.7  1.2  ...  7.7  3.7  1.6  0.8
# 1   23  66  42  24  24.5   9.5  3.5   8.5  41.4  1.3  ...  2.4  3.4  1.3  0.8
# 2   26  55  37  18  15.8   6.3  2.2   4.8  46.8  0.9  ...  1.8  0.7  0.8  0.4
# 3   21  11   3   8  10.2   2.9  1.1   2.5  42.9  0.5  ...  0.9  0.4  0.2  0.4
# 4   23  33   9  24  11.2   3.0  1.1   2.8  38.0  0.6  ...  1.4  0.5  0.2  0.2
#
#    BLK   PF    FP   DD2  TD3  +/-
# 0  0.6  2.0  31.9  20.0  1.0 -1.1
# 1  0.2  1.8  19.3   3.0  0.0  1.7
# 2  0.4  1.4  11.1   0.0  0.0 -1.5
# 3  0.0  1.5   5.5   0.0  0.0  4.5
# 4  0.1  1.5   6.3   0.0  0.0 -1.7
#
# [5 rows x 27 columns]

# %%
testx_scaler = scaler.fit(test_x)

X_test_scaled = testx_scaler.transform(test_x)

# %%
current_predictions = rf_model.predict(test_x)
# Out:
# /Users/mollysprecher/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
comparison_df = pd.DataFrame(current_predictions, columns=["predictions"])
comparison_df['real'] = test_y
comparison_df.head(20)

new_df = raw_df.merge(comparison_df, left_index=True, right_index=True)
new_df = new_df.drop('real', axis=1)
new_df = new_df.drop('Unnamed: 0', axis=1)
new_df.head(30)
# Out:
#                 PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM  ...  \
# 0         Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4  5.4  ...
# 1        Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5  3.5  ...
# 2          Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3  2.2  ...
# 3          Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9  1.1  ...
# 4    Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1  ...
# 5           Al Horford  PHI   34  2019-20  67  39  28  30.2  11.9  4.8  ...
# 6      Al-Farouq Aminu  ORL   29  2019-20  18   7  11  21.1   4.3  1.4  ...
# 7           Alec Burks  PHI   28  2019-20  66  21  45  26.6  15.0  4.9  ...
# 8       Alen Smailagic  GSW   19  2019-20  14   1  13   9.9   4.2  1.4  ...
# 9          Alex Caruso  LAL   26  2019-20  64  48  16  18.4   5.5  1.9  ...
# 10            Alex Len  SAC   27  2019-20  55  18  37  17.6   8.0  3.2  ...
# 11    Alfonzo McKinnie  CLE   27  2019-20  40  11  29  14.8   4.6  1.8  ...
# 12       Alize Johnson  IND   24  2019-20  17  10   7   6.9   2.0  0.7  ...
# 13        Allen Crabbe  MIN   28  2019-20  37   5  32  17.6   4.6  1.7  ...
# 14       Allonzo Trier  NYK   24  2019-20  24   2  22  12.1   6.5  2.1  ...
# 15     Amile Jefferson  ORL   27  2019-20  18   5  13   4.1   0.8  0.3  ...
# 16         Amir Coffey  LAC   23  2019-20  18  11   7   8.8   3.2  1.3  ...
# 17      Andre Drummond  CLE   26  2019-20  57  21  36  33.0  17.7  7.3  ...
# 18      Andre Iguodala  MIA   36  2019-20  21  10  11  19.9   4.6  1.8  ...
# 19      Andre Roberson  OKC   28  2019-20   7   3   4  12.4   2.9  1.1  ...
# 20      Andrew Wiggins  GSW   25  2019-20  54  15  39  34.4  21.8  8.1  ...
# 21     Anfernee Simons  POR   21  2019-20  70  32  38  20.7   8.3  3.1  ...
# 22          Ante Zizic  CLE   23  2019-20  22   4  18  10.0   4.4  1.9  ...
# 23       Anthony Davis  LAL   27  2019-20  62  46  16  34.4  26.1  8.9  ...
# 24    Anthony Tolliver  MEM   35  2019-20  55  24  31  15.9   3.6  1.2  ...
# 25  Antonius Cleveland  DAL   26  2019-20  11   6   5   4.2   1.0  0.4  ...
# 26    Anzejs Pasecniks  WAS   24  2019-20  27   9  18  16.2   5.8  2.3  ...
# 27         Aron Baynes  PHX   33  2019-20  42  19  23  22.2  11.5  4.4  ...
# 28       Austin Rivers  HOU   27  2019-20  68  43  25  23.4   8.8  3.1  ...
# 29       Avery Bradley  LAL   29  2019-20  49  36  13  24.2   8.6  3.5  ...
#
#     TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings  predictions
# 0   1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0         94.0
# 1   1.3  0.8  0.2  1.8  19.3   3.0  0.0  1.7      76.0         93.0
# 2   0.8  0.4  0.4  1.4  11.1   0.0  0.0 -1.5      71.0         84.0
# 3   0.2  0.4  0.0  1.5   5.5   0.0  0.0  4.5      68.0         90.0
# 4   0.2  0.2  0.1  1.5   6.3   0.0  0.0 -1.7      71.0         84.0
# 5   1.2  0.8  0.9  2.1  30.0   6.0  0.0  1.9      80.0         94.0
# 6   0.9  1.0  0.4  1.5  15.3   1.0  0.0 -1.9      75.0         87.0
# 7   1.4  0.9  0.3  1.9  26.7   1.0  0.0 -3.4      77.0         94.0
# 8   0.8  0.2  0.3  1.0   8.6   0.0  0.0 -0.6      71.0         88.0
# 9   0.8  1.1  0.3  1.5  14.0   0.0  0.0  3.8      74.0         90.0
# 10  1.0  0.4  0.9  2.3  19.2   8.0  0.0 -2.0      76.0         94.0
# 11  0.7  0.6  0.2  1.8  10.1   1.0  0.0 -2.3      70.0         84.0
# 12  0.4  0.2  0.1  0.7   6.5   1.0  0.0  1.5      70.0         85.0
# 13  0.5  0.4  0.1  1.3   9.6   0.0  0.0 -6.0      72.0         84.0
# 14  0.9  0.1  0.2  1.2   9.6   0.0  0.0 -3.0      75.0         88.0
# 15  0.2  0.1  0.2  0.4   3.2   0.0  0.0  1.0      69.0         77.0
# 16  0.4  0.3  0.1  1.1   6.2   0.0  0.0 -0.3      68.0         84.0
# 17  3.6  1.9  1.6  3.5  47.0  47.0  0.0 -3.4      85.0         94.0
# 18  1.2  0.7  1.0  1.7  16.4   0.0  0.0 -1.2      76.0         89.0
# 19  0.3  0.1  0.4  1.9   9.8   0.0  0.0 -0.4      72.0         84.0
# 20  2.4  0.8  1.0  2.4  36.3   4.0  1.0 -3.7      82.0         94.0
# 21  0.9  0.4  0.1  1.9  13.6   1.0  0.0 -3.5      72.0         88.0
# 22  0.5  0.3  0.2  1.2   9.6   1.0  0.0  0.6      73.0         87.0
# 23  2.5  1.5  2.3  2.5  50.9  29.0  0.0  3.9      95.0         96.0
# 24  0.6  0.3  0.2  1.3   9.2   1.0  0.0 -1.9      71.0         84.0
# 25  0.2  0.1  0.3  0.7   2.8   0.0  0.0 -1.1      67.0         78.0
# 26  0.9  0.3  0.4  2.8  13.0   0.0  0.0 -0.1      72.0         88.0
# 27  1.2  0.2  0.5  3.4  21.8   3.0  0.0 -1.1      78.0         94.0
# 28  0.7  0.7  0.1  1.9  16.2   0.0  0.0  1.2      75.0         88.0
# 29  1.0  0.9  0.1  2.2  15.4   0.0  0.0  3.7      74.0         90.0
#
# [30 rows x 32 columns]
