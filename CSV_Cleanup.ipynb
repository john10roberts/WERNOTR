# %%
# Initial imports
import pandas as pd

# %%
# Load in NBA data.
file_path = "Resources/nba_rankings_2014-2020.csv"
nba_df = pd.read_csv(file_path, index_col= 0)
nba_df.head(10)
# Out:
#               PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM  ...  \
# 0       Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4  5.4  ...
# 1      Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5  3.5  ...
# 2        Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3  2.2  ...
# 3        Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9  1.1  ...
# 4  Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1  ...
# 5         Al Horford  PHI   34  2019-20  67  39  28  30.2  11.9  4.8  ...
# 6    Al-Farouq Aminu  ORL   29  2019-20  18   7  11  21.1   4.3  1.4  ...
# 7         Alec Burks  PHI   28  2019-20  66  21  45  26.6  15.0  4.9  ...
# 8     Alen Smailagic  GSW   19  2019-20  14   1  13   9.9   4.2  1.4  ...
# 9        Alex Caruso  LAL   26  2019-20  64  48  16  18.4   5.5  1.9  ...
#
#    AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  rankings
# 0  3.7  1.6  0.8  0.6  2.0  31.9  20.0  1.0 -1.1      80.0
# ...

# %%
nba_df = nba_df.dropna()

# %%
nba_19_20 = nba_df[nba_df["SEASON"] == "2019-20"]

# %%
nba_19_20.shape
# Out:
# (507, 31)

# %%
nba_19_20
# Out:
#                 PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM  ...  \
# 0         Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4  5.4  ...
# 1        Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5  3.5  ...
# 2          Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3  2.2  ...
# 3          Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9  1.1  ...
# 4    Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1  ...
# ..                 ...  ...  ...      ...  ..  ..  ..   ...   ...  ...  ...
# 623        Zach LaVine  CHI   25  2019-20  60  20  40  34.8  25.5  9.0  ...
# 624   Zach Norvell Jr.  GSW   22  2019-20   5   2   3   8.2   2.0  0.6  ...
# 628       Zhaire Smith  PHI   21  2019-20   7   3   4   4.6   1.1  0.4  ...
# 629    Zion Williamson  NOP   19  2019-20  24  11  13  27.8  22.5  8.8  ...
# 630     Zylan Cheatham  NOP   24  2019-20   4   2   2  12.8   3.0  1.5  ...
#
# ...

# %%
nba_19_20 = nba_19_20.rename(columns={"FG%":"FGP", "3PM":"TPM", "3PA":"TPA", "3P%":"TPP", "FT%":"FTP", "+/-":"PON"})

# %%
nba_19_20
# Out:
#                 PLAYER TEAM  AGE   SEASON  GP   W   L   MIN   PTS  FGM  ...  \
# 0         Aaron Gordon  ORL   24  2019-20  62  30  32  32.5  14.4  5.4  ...
# 1        Aaron Holiday  IND   23  2019-20  66  42  24  24.5   9.5  3.5  ...
# 2          Abdel Nader  OKC   26  2019-20  55  37  18  15.8   6.3  2.2  ...
# 3          Adam Mokoka  CHI   21  2019-20  11   3   8  10.2   2.9  1.1  ...
# 4    Admiral Schofield  WAS   23  2019-20  33   9  24  11.2   3.0  1.1  ...
# ..                 ...  ...  ...      ...  ..  ..  ..   ...   ...  ...  ...
# 623        Zach LaVine  CHI   25  2019-20  60  20  40  34.8  25.5  9.0  ...
# 624   Zach Norvell Jr.  GSW   22  2019-20   5   2   3   8.2   2.0  0.6  ...
# 628       Zhaire Smith  PHI   21  2019-20   7   3   4   4.6   1.1  0.4  ...
# 629    Zion Williamson  NOP   19  2019-20  24  11  13  27.8  22.5  8.8  ...
# 630     Zylan Cheatham  NOP   24  2019-20   4   2   2  12.8   3.0  1.5  ...
#
# ...

# %%
nba_19_20.to_csv("NBA_Cleaned", index=False)
